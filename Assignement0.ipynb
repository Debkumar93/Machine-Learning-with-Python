# %% [markdown]
# <a href="https://colab.research.google.com/github/Debkumar93/Machine-Learning-with-Python/blob/master/Assignement0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = 6

if x%2 ==0:
  print("Number is Even")
else:
  print("Number is Odd")
# Out:
# Number is Even

# %%
y = input("Enter a string :")

word_list = y.split() # Splits by whitespace

print(word_list)
# Out:
# Enter a string :I love my India
# ['I', 'love', 'my', 'India']

# %%
word_list.sort()
print(word_list)
# Out:
# ['I', 'India', 'love', 'my']

# %%
for i in range(1000, 3000):
  if i % 3 == 0:
    print(f"Number is odd for {i}" )
# Out:
# Number is odd for 1002
# Number is odd for 1005
# Number is odd for 1008
# Number is odd for 1011
# Number is odd for 1014
# Number is odd for 1017
# Number is odd for 1020
# Number is odd for 1023
# Number is odd for 1026
# Number is odd for 1029
# Number is odd for 1032
# Number is odd for 1035
# Number is odd for 1038
# Number is odd for 1041
# Number is odd for 1044
# Number is odd for 1047
# Number is odd for 1050
# Number is odd for 1053
# Number is odd for 1056
# Number is odd for 1059
# Number is odd for 1062
# Number is odd for 1065
# Number is odd for 1068
# Number is odd for 1071
# Number is odd for 1074
# Number is odd for 1077
# Number is odd for 1080
# Number is odd for 1083
# Number is odd for 1086
# Number is odd for 1089
# Number is odd for 1092
# Number is odd for 1095
# Number is odd for 1098
# Number is odd for 1101
# Number is odd for 1104
# Number is odd for 1107
# Number is odd for 1110
# Number is odd for 1113
# Number is odd for 1116
# Number is odd for 1119
# ...

# %%
l = "Edureka123"
number = letters = 0
for c in l:
  if c.isalpha():
    letters=letters+1
  elif c.isdigit():
    number = number+1
  else:
    pass
print(letters)
print(number)
# Out:
# 7
# 3

# %%
number = 121
res = str(number) == str(number)[::-1]
print ("Is the number palindrome ? : " + str(res))
# Out:
# Is the number palindrome ? : True
